# %%
import tensorflow as tf
def tables(x):
  for i in range(1,11):
    print(i,"X",x,"=",i*x)
for i in range(1,101):
  print("\n**********************",i,"th table******************************\n")
  tables(i)
# Out:
# ********************** 1 th table******************************
#
# 1 X 1 = 1
# 2 X 1 = 2
# 3 X 1 = 3
# 4 X 1 = 4
# 5 X 1 = 5
# 6 X 1 = 6
# 7 X 1 = 7
# 8 X 1 = 8
# 9 X 1 = 9
# 10 X 1 = 10
#
# ********************** 2 th table******************************
#
# 1 X 2 = 2
# 2 X 2 = 4
# 3 X 2 = 6
# 4 X 2 = 8
# 5 X 2 = 10
# 6 X 2 = 12
# 7 X 2 = 14
# 8 X 2 = 16
# 9 X 2 = 18
# 10 X 2 = 20
#
# ********************** 3 th table******************************
#
# 1 X 3 = 3
# 2 X 3 = 6
# 3 X 3 = 9
# 4 X 3 = 12
# 5 X 3 = 15
# 6 X 3 = 18
# 7 X 3 = 21
# 8 X 3 = 24
# 9 X 3 = 27
# 10 X 3 = 30
#
# ********************** 4 th table******************************
#
# 1 X 4 = 4
# 2 X 4 = 8
# 3 X 4 = 12
# 4 X 4 = 16
# 5 X 4 = 20
# 6 X 4 = 24
# 7 X 4 = 28
# 8 X 4 = 32
# 9 X 4 = 36
# 10 X 4 = 40
#
# ********************** 5 th table******************************
#
# 1 X 5 = 5
# 2 X 5 = 10
# 3 X 5 = 15
# 4 X 5 = 20
# 5 X 5 = 25
# 6 X 5 = 30
# 7 X 5 = 35
# 8 X 5 = 40
# 9 X 5 = 45
# 10 X 5 = 50
#
# ...
